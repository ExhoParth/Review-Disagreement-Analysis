# %%
import pandas as pd

# %% [markdown]
# IIT-Patna-RA23
# https://github.com/sandeep82945/Contradiction-in-Peer-Review

# %%
iitp = pd.read_csv("Sdata_annotated.csv")
iitp
# Out:
#        Unnamed: 0.1  Unnamed: 0        paper_id  pair_id  \
# 0                 0           0  ICLR_2019_1401        3
# 1                 1           1    NIPS_2016_89        3
# 2                 2           2    NIPS_2016_89        4
# 3                 3           3    NIPS_2016_89        5
# 4                 4           4    NIPS_2016_89        5
# ...             ...         ...             ...      ...
# 47970         47970       47970   ICLR_2020_244        1
# 47971         47971       47971   ICLR_2020_244        1
# 47972         47972       47972   ICLR_2020_584        1
# 47973         47973       47973   NIPS_2019_449        1
# 47974         47974       47974   ICLR_2020_733        1
#
#                                               hypothesis  \
# 0      further the paper makes several misleading cla...
# 1      4 .i like the key idea and the speedup is very...
# 2      the idea to use sampling is nice but the analy...
# ...

# %% [markdown]
# ASAP https://www.kaggle.com/datasets/jonauskis/asap-review

# %%
asap1 = pd.read_json('archive/aspect_data/review_with_aspect.jsonl',lines=True)
asap1
# Out:
#                    id                                               text  \
# 0      ICLR_2020_1123  This work studies the predictive uncertainty i...
# 1       ICLR_2018_813  Summary : This paper proposes a new approach t...
# 2       NIPS_2019_796  The paper proposes a graph neural network base...
# 3       ICLR_2018_726  Summary : This paper proposes an encoder-decod...
# 4       NIPS_2016_477  The authors present sharp criteria for l_1-spa...
# ...               ...                                                ...
# 25981   ICLR_2020_610  In this work , a novel inverse constraint lear...
# 25982   ICLR_2017_378  I find the general direction of the work is pr...
# 25983  ICLR_2020_1164  This paper investigates the problem of learnin...
# 25984   NIPS_2018_998  This paper considers a generalized version of ...
# 25985   ICLR_2020_905  The authors present a model for time series wh...
#
#                                                   labels
# ...

# %%
asap2 = pd.read_json('archive/ICLR_2020/ICLR_2020_content/ICLR_2020_1000_content.json')
asap2
# Out:
#                                  name  \
# source             ICLR_2020_1000.pdf
# title              ICLR_2020_1000.pdf
# authors            ICLR_2020_1000.pdf
# emails             ICLR_2020_1000.pdf
# sections           ICLR_2020_1000.pdf
# references         ICLR_2020_1000.pdf
# referenceMentions  ICLR_2020_1000.pdf
# year               ICLR_2020_1000.pdf
# abstractText       ICLR_2020_1000.pdf
# creator            ICLR_2020_1000.pdf
#
#                                                             metadata  \
# source                                                           CRF
# title                            CROSS-ITERATION BATCH NORMALIZATION
# authors                                                           []
# emails                                                            []
# sections           [{'heading': '1 INTRODUCTION', 'text': 'Batch ...
# references         [{'title': 'Deeplab: Semantic image segmentati...
# ...

# %%
asap3 = pd.read_json('archive/ICLR_2020/ICLR_2020_paper/ICLR_2020_1000_paper.json')
asap3
# Out:
#                id conference decision  \
# 0  ICLR_2020_1000       ICLR   Reject
# 1  ICLR_2020_1000       ICLR   Reject
# 2  ICLR_2020_1000       ICLR   Reject
# 3  ICLR_2020_1000       ICLR   Reject
# 4  ICLR_2020_1000       ICLR   Reject
# 5  ICLR_2020_1000       ICLR   Reject
#
#                                                  url hasContent hasReview  \
# 0  http://openreview.net/pdf/cb4db66f6ded623b263b...       true      true
# 1  http://openreview.net/pdf/cb4db66f6ded623b263b...       true      true
# 2  http://openreview.net/pdf/cb4db66f6ded623b263b...       true      true
# 3  http://openreview.net/pdf/cb4db66f6ded623b263b...       true      true
# 4  http://openreview.net/pdf/cb4db66f6ded623b263b...       true      true
# 5  http://openreview.net/pdf/cb4db66f6ded623b263b...       true      true
#
#                                  title       authors
# 0  Cross-Iteration Batch Normalization  Zhuliang Yao
# 1  Cross-Iteration Batch Normalization       Yue Cao
# ...

# %%
asap4 = pd.read_json('archive/ICLR_2020/ICLR_2020_review/ICLR_2020_1000_review.json')
asap4
# Out:
#                id                                            reviews  \
# 0  ICLR_2020_1000  {'review': 'The paper tackles the problem of b...
# 1  ICLR_2020_1000  {'review': 'Paper summary: This paper proposes...
# 2  ICLR_2020_1000  {'review': 'This paper proposes a novel Cross-...
#
#                                           metaReview
# 0  This paper proposes cross-iteration batch norm...
# 1  This paper proposes cross-iteration batch norm...
# 2  This paper proposes cross-iteration batch norm...

# %% [markdown]
#  PeerRead  (https://paperswithcode.com/dataset/peerread; https://huggingface.co/datasets/allenai/peer_read;) , (https://github.com/allenai/PeerRead)

# %%
import json

with open('PeerRead-master/data/arxiv.cs.ai_2007-2017/train/reviews/0804.2155.json') as file:
    data = json.load(file)

print(data)
# Out:
# {'conference': 'AAAI', 'VERSION': 'v1', 'DATE_OF_SUBMISSION': '14-Apr-2008', 'title': 'From Qualitative to Quantitative Proofs of Security Properties Using First-Order Conditional Logic', 'abstract': 'A first-order conditional logic is considered, with semantics given by a variant of epsilon-semantics, where p -&gt; q means that Pr(q | p) approaches 1 super-polynomially --faster than any inverse polynomial. This type of convergence is needed for reasoning about security protocols. A complete axiomatization is provided for this semantics, and it is shown how a qualitative proof of the correctness of a security protocol can be automatically converted to a quantitative proof appropriate for reasoning about concrete security.', 'histories': [['v1', 'Mon, 14 Apr 2008 12:06:04 GMT  (34kb)', 'http://arxiv.org/abs/0804.2155v1', None]], 'reviews': [], 'SUBJECTS': 'cs.CR cs.AI cs.LO', 'authors': ['joseph y halpern'], 'accepted': True, 'id': '0804.2155'}

# %% [markdown]
# COMPARE https://paperswithcode.com/dataset/compare

# %%
cmp = pd.read_excel('COMPARE-main/dataset/train.xlsx')
cmp
# Out:
#      UID              PID     Dec  \
# 0    595   2018_SJx9GQb0-  Accept
# 1    178   2018_H1LAqMbRW  Reject
# 2     50  2019_HJfwJ2A5KX  Accept
# 3    593   2018_SJx9GQb0-  Accept
# 4    473   2017_S1Bb3D5gg  Accept
# ..   ...              ...     ...
# 291  108   2017_ByToKu9ll  Reject
# 292  155   2017_HyTqHL5xg  Accept
# 293  278  2020_ryxC6kSYPr  Accept
# 294   40  2019_HJfwJ2A5KX  Accept
# 295  130   2017_HyTqHL5xg  Accept
#
#                                                   Sent  MComp  Cat  SubCat
# 0    If the authors fix the theoretical analysis an...      1    D     0.0
# 1    Would it be possible to include a non-determin...      1    B     0.0
# 2    Hence, failing to compare to results of at lea...      1    B     1.0
# 3    One of the main problems is that the largest d...      1    D     0.0
# 4    The tasks 1-5 are also completely deterministi...      1    T     0.0
# ..                                                 ...    ...  ...     ...
# ...

# %% [markdown]
# DISAPERE (https://github.com/nnkennard/DISAPERE)

# %%
di2 = pd.read_json('disapere/data2/arxiv.cs.ai_2007-2017/train/parsed_pdfs/0804.2155.pdf.json')
di2
# Out:
#                             name  \
# source             0804.2155.pdf
# title              0804.2155.pdf
# authors            0804.2155.pdf
# emails             0804.2155.pdf
# sections           0804.2155.pdf
# references         0804.2155.pdf
# referenceMentions  0804.2155.pdf
# year               0804.2155.pdf
# abstractText       0804.2155.pdf
# creator            0804.2155.pdf
#
#                                                             metadata
# source                                                           CRF
# title              From Qualitative to Quantitative Proofs of Sec...
# authors                                           [Joseph Y. Halper]
# emails                                      [halpern@cs.cornell.edu]
# sections           [{'heading': None, 'text': 'ar X
# iv :0
# 80 4.
# 2...
# references         [{'title': 'and Rogaway', 'author': ['M. Abadi...
# referenceMentions                                                 []
# ...

# %% [markdown]
#  MReD (https://github.com/Shen-Chenhui/MReD)

# %%
cla = pd.read_csv('MReD-master/MReD-master/classification/data/train.txt',sep='\t')
cla
# Out:
#          2018-1  \
# 0        2018-1
# 1        2018-1
# 2        2018-1
# 3        2018-1
# 4        2018-1
# ...         ...
# 37225  2021-895
# 37226  2021-895
# 37227  2021-895
# 37228  2021-895
# 37229  2021-895
#
#       This paper analyzes a problem with the convergence of Adam, and presents a solution.  \
# 0      It identifies an error in the convergence proo...
# 1      The paper then repairs the algorithm in a way ...
# 2      There ought to be a lot of interest in this pa...
# 3              The fix is both principled and practical.
# 4      Overall, this is a strong paper, and I recomme...
# ...                                                  ...
# 37225  *CONF* guidelines clearly states that "...Note...
# 37226  Even more worrisome is the fact that authors d...
# 37227  Hence, I decided to reject the paper since the...
# 37228  On the other hand, I think the paper can be re...
# 37229  I suggest authors to revise the claims more pr...
#
#                abstract
# ...

# %%
summ = pd.read_csv('MReD-master/MReD-master/summarization/abstractive/filtered_controlled_data/test_concat_seg-ctrl.csv')
summ
# Out:
#                                                   text  \
# 0    strength | decision ==> This paper proposes a ...
# 1    strength ==> This paper presents a set of stud...
# 2    abstract | weakness | rebuttal_process | stren...
# 3    abstract | strength | rebuttal_process | ratin...
# 4    abstract | strength ==> This paper studies pro...
# ..                                                 ...
# 669  abstract | weakness ==> Summary: <sep> This pa...
# 670  abstract | strength | weakness | decision ==> ...
# 671  abstract | weakness | decision ==> The authors...
# 672  abstract | rebuttal_process | weakness | rebut...
# 673  abstract | weakness | decision ==> The paper i...
#
#                                                summary
# 0    High quality paper, appreciated by reviewers, ...
# 1    Important problem (analyzing the properties of...
# 2    This paper presents a sampling inference metho...
# 3    The paper presents a modification of the Winog...
# ...

# %% [markdown]
# ArgSciChat (https://github.com/UKPLab/acl2023-argscichat)

# %%
ag = pd.read_csv('acl2023-argscichat-main/acl2023-argscichat-main/argscichat_allennlp/argscichat_intents/dataset.csv')
ag
# Out:
#               Role  Message Number  Sentence Number  \
# 0        Proponent               0                0
# 1        Proponent               0                1
# 2        Proponent               2                0
# 3        Proponent               2                1
# 4        Proponent               4                0
# ..             ...             ...              ...
# 876  Domain Expert              11                1
# 877  Domain Expert              13                0
# 878  Domain Expert              13                1
# 879  Domain Expert              15                0
# 880  Domain Expert              17                0
#
#                                               Sentence             Tag
# 0                                               Hello!           Intro
# 1    What is the type of knowledge that is injected...        Ask_Info
# 2                                         Interesting!    Give_Opinion
# ...

# %%
ag2 = pd.read_json('acl2023-argscichat-main/acl2023-argscichat-main/argscichat_allennlp/argscichat_train_dev/fold_0_test.json')
ag2
# Out:
#                       Analyzing Political Parody in Social Media  \
# id                    Analyzing Political Parody in Social Media
# title                 Analyzing Political Parody in Social Media
# content        [Parody is a figurative device used to imitate...
# message_pairs  [{'id': 'Analyzing Political Parody in Social ...
#
#               From Zero to Hero: Human-In-The-Loop Entity Linking in Low Resource Domains
# id             From Zero to Hero: Human-In-The-Loop Entity Li...
# title          From Zero to Hero: Human-In-The-Loop Entity Li...
# content        [Entity linking (EL) is concerned with disambi...
# message_pairs  [{'id': 'From Zero to Hero: Human-In-The-Loop ...
